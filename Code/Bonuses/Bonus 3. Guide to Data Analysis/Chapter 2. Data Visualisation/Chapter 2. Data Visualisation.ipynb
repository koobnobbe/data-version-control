# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# ## Import Data

# %%
data = pd.read_csv('./data/penguins_size.csv')
data.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# ## Seaborn styles, context and palette

# %%
# Example data
x = np.random.randint(low=1, high=11, size=30)
y = x + np.random.randint(1, 6, size=30)

sb.set_style('white')
plt.title('Title')
plt.xlabel('x lablel')
plt.ylabel('y lablel')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_style('dark')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_style('whitegrid')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_style('darkgrid')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_style('white')
sb.set_context('notebook')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_context('paper')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_context('poster')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.set_context('talk')
plt.scatter(x=x, y=y, color='orange')

# %%
sb.palplot(sb.color_palette('Oranges_r', 11))

# %%
sb.set_palette('Oranges_r')
sb.set_context('paper')

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Distribution Plots

# %%
sb.distplot(data['culmen_depth_mm'])

# %%
sb.rugplot(data['culmen_depth_mm'])

# %%
sb.kdeplot(data['culmen_depth_mm'])

# %%
#FacetGrid with Kdeplot
sb.FacetGrid(data,hue="species",height=5)\
             .map(sb.kdeplot,"culmen_depth_mm")\
             .add_legend()
plt.ioff()

# %%
sb.jointplot(x="culmen_length_mm",y="culmen_depth_mm", data=data)

# %%
sb.jointplot(x="culmen_length_mm",y="culmen_depth_mm", data=data, kind='kde')

# %%
sb.pairplot(data)

# %% [markdown]
# ### Continuous & Categorical Variables Relationships

# %%
sb.stripplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %%
sb.swarmplot(x="species",y="culmen_depth_mm",data=data,hue="species")
# Out:
# G:\Anaconda3\lib\site-packages\seaborn\categorical.py:1326: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# G:\Anaconda3\lib\site-packages\seaborn\categorical.py:1330: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sb.boxplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %%
data.boxplot(by="species",figsize=(10,8), color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2FFEECB48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2FFF09808>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001D2FFF3FE88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001D2FFF7A888>]],
#       dtype=object)

# %%
box_strip_combo_fig=sb.boxplot(x="species",y="culmen_depth_mm",data=data)
box_strip_combo_fig=sb.stripplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %%
sb.boxenplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %%
sb.violinplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %%
sb.pointplot(x="species",y="culmen_depth_mm",data=data,hue="species")

# %% [markdown]
# ### Continuous Variables Relationships

# %%
sb.scatterplot(x="culmen_length_mm",y="culmen_depth_mm", data=data)

# %%
sb.lineplot(x="culmen_length_mm",y="culmen_depth_mm", data=data)

# %% [markdown]
# ### Statistical Model

# %%
data.describe().plot(kind="area",fontsize=20, figsize=(20,8),table=False)
plt.xlabel("Statistics")
plt.ylabel('Value')
plt.title("Statistics of PalmerPengins Dataset")
# Out:
# Text(0.5, 1.0, 'Statistics of PalmerPengins Dataset')

# %%
sb.residplot(x="culmen_length_mm",y="culmen_depth_mm", data=data)

# %%
sb.lmplot(x="culmen_length_mm",y="culmen_depth_mm", data=data)

# %%
sb.heatmap(data.corr(),vmin=-1,vmax=1,annot=True)
